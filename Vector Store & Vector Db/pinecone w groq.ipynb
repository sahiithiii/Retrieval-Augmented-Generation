# %% [markdown]
# ### Pinecone Vector DB

# %%
## Create your index and apikey from here https://www.pinecone.io/
from dotenv import load_dotenv
import os
os.environ["PINECONE_API_KEY"] = "pcsk_2hXkJx_D1PvWB1haEz8jSyzYaNdDF9qtvPmK2BMoJAzmKr3T4u3RfDWC7gCgDK3BquDvsx"
# optional check

# %%
from pinecone import Pinecone
pc=Pinecone(api_key=api_key)

# %%
from langchain_huggingface import HuggingFaceEmbeddings

embeddings = HuggingFaceEmbeddings(model="sentence-transformers/all-mpnet-base-v2")

# %%
from pinecone import ServerlessSpec

index_name = "test-cone"  # change if desired

if not pc.has_index(index_name):
    pc.create_index(
        name=index_name,
        dimension=1024,
        metric="cosine",
        spec=ServerlessSpec(cloud="aws", region="us-east-1"),
    )

index = pc.Index(index_name)
# Out:
# ---------------------------------------------------------------------------
# UnauthorizedException                     Traceback (most recent call last)
# Cell In[14], line 5
#       1 from pinecone import ServerlessSpec
#       3 index_name = "test-cone"  # change if desired
# ----> 5 if not pc.has_index(index_name):
#       6     pc.create_index(
#       7         name=index_name,
#       8         dimension=1024,
#       9         metric="cosine",
#      10         spec=ServerlessSpec(cloud="aws", region="us-east-1"),
#      11     )
#      13 index = pc.Index(index_name)
#
# File d:\project\myvenv\Lib\site-packages\pinecone\pinecone.py:393, in Pinecone.has_index(self, name)
#     392 def has_index(self, name: str) -> bool:
# --> 393     return self.db.index.has(name=name)
#
# File d:\project\myvenv\Lib\site-packages\pinecone\utils\require_kwargs.py:14, in require_kwargs.<locals>.wrapper(*args, **kwargs)
#       9     param_names = list(inspect.signature(func).parameters.keys())[1:]  # Skip self
#      10     raise TypeError(
#      11         f"{func.__name__}() requires keyword arguments. "
#      12         f"Please use {func.__name__}({', '.join(f'{name}=value' for name in param_names)})"
#      13     )
# ---> 14 return func(*args, **kwargs)
#
# File d:\project\myvenv\Lib\site-packages\pinecone\db_control\resources\sync\index.py:214, in IndexResource.has(self, name)
#     212 @require_kwargs
#     213 def has(self, *, name: str) -> bool:
# --> 214     if name in self.list().names():
#     215         return True
#     216     else:
#
# File d:\project\myvenv\Lib\site-packages\pinecone\utils\require_kwargs.py:14, in require_kwargs.<locals>.wrapper(*args, **kwargs)
#       9     param_names = list(inspect.signature(func).parameters.keys())[1:]  # Skip self
#      10     raise TypeError(
#      11         f"{func.__name__}() requires keyword arguments. "
#      12         f"Please use {func.__name__}({', '.join(f'{name}=value' for name in param_names)})"
#      13     )
# ---> 14 return func(*args, **kwargs)
#
# File d:\project\myvenv\Lib\site-packages\pinecone\db_control\resources\sync\index.py:200, in IndexResource.list(self)
#     198 @require_kwargs
#     199 def list(self) -> IndexList:
# --> 200     response = self._index_api.list_indexes()
#     201     return IndexList(response)
#
# File d:\project\myvenv\Lib\site-packages\pinecone\openapi_support\endpoint.py:102, in Endpoint.__call__(self, *args, **kwargs)
#      91 def __call__(self, *args, **kwargs):
#      92     """This method is invoked when endpoints are called
#      93     Example:
#      94
#    (...)    100
#     101     """
# --> 102     return self.callable(self, *args, **kwargs)
#
# File d:\project\myvenv\Lib\site-packages\pinecone\core\openapi\db_control\api\manage_indexes_api.py:1161, in ManageIndexesApi.__init__.<locals>.__list_indexes(self, **kwargs)
#    1127 """List indexes  # noqa: E501
#    1128
#    1129 List all indexes in a project.  # noqa: E501
#    (...)   1158         thread.
#    1159 """
#    1160 kwargs = self._process_openapi_kwargs(kwargs)
# -> 1161 return self.call_with_http_info(**kwargs)
#
# File d:\project\myvenv\Lib\site-packages\pinecone\openapi_support\endpoint.py:134, in Endpoint.call_with_http_info(self, **kwargs)
#     124 params = EndpointUtils.gather_params(
#     125     attribute_map=self.attribute_map,
#     126     location_map=self.location_map,
#    (...)    129     kwargs=kwargs,
#     130 )
#     132 HeaderUtil.prepare_headers(headers_map=self.headers_map, params=params)
# --> 134 return self.api_client.call_api(
#     135     self.settings["endpoint_path"],
#     136     self.settings["http_method"],
#     137     path_params=params["path"],
#     138     query_params=params["query"],
#     139     header_params=params["header"],
#     140     body=params["body"],
#     141     post_params=params["form"],
#     142     files=params["file"],
#     143     response_type=self.settings["response_type"],
#     144     auth_settings=self.settings["auth"],
#     145     async_req=kwargs["async_req"],
#     146     async_threadpool_executor=kwargs.get("async_threadpool_executor", None),
#     147     _check_type=kwargs["_check_return_type"],
#     148     _return_http_data_only=kwargs["_return_http_data_only"],
#     149     _preload_content=kwargs["_preload_content"],
#     150     _request_timeout=kwargs["_request_timeout"],
#     151     _host=_host,
#     152     collection_formats=params["collection_format"],
#     153 )
#
# File d:\project\myvenv\Lib\site-packages\pinecone\openapi_support\api_client.py:306, in ApiClient.call_api(self, resource_path, method, path_params, query_params, header_params, body, post_params, files, response_type, auth_settings, async_req, async_threadpool_executor, _return_http_data_only, collection_formats, _preload_content, _request_timeout, _host, _check_type)
#     285     return self.threadpool_executor.submit(
#     286         self.__call_api,
#     287         resource_path,
#    (...)    302         _check_type,
#     303     )
#     305 if not async_req:
# --> 306     return self.__call_api(
#     307         resource_path,
#     308         method,
#     309         path_params,
#     310         query_params,
#     311         header_params,
#     312         body,
#     313         post_params,
#     314         files,
#     315         response_type,
#     316         auth_settings,
#     317         _return_http_data_only,
#     318         collection_formats,
#     319         _preload_content,
#     320         _request_timeout,
#     321         _host,
#     322         _check_type,
#     323     )
#     325 return self.pool.apply_async(
#     326     self.__call_api,
#     327     (
#    (...)    344     ),
#     345 )
#
# File d:\project\myvenv\Lib\site-packages\pinecone\openapi_support\api_client.py:182, in ApiClient.__call_api(self, resource_path, method, path_params, query_params, header_params, body, post_params, files, response_type, auth_settings, _return_http_data_only, collection_formats, _preload_content, _request_timeout, _host, _check_type)
#     180 except PineconeApiException as e:
#     181     e.body = e.body.decode("utf-8")
# --> 182     raise e
#     184 self.last_response = response_data
#     186 return_data = response_data
#
# File d:\project\myvenv\Lib\site-packages\pinecone\openapi_support\api_client.py:170, in ApiClient.__call_api(self, resource_path, method, path_params, query_params, header_params, body, post_params, files, response_type, auth_settings, _return_http_data_only, collection_formats, _preload_content, _request_timeout, _host, _check_type)
#     161 url = build_request_url(
#     162     config=config,
#     163     processed_path_params=path_params_tuple,
#     164     resource_path=resource_path,
#     165     _host=_host,
#     166 )
#     168 try:
#     169     # perform request and return response
# --> 170     response_data = self.request(
#     171         method,
#     172         url,
#     173         query_params=processed_query_params,
#     174         headers=headers_tuple,
#     175         post_params=processed_post_params,
#     176         body=body,
#     177         _preload_content=_preload_content,
#     178         _request_timeout=_request_timeout,
#     179     )
#     180 except PineconeApiException as e:
#     181     e.body = e.body.decode("utf-8")
#
# File d:\project\myvenv\Lib\site-packages\pinecone\openapi_support\api_client.py:360, in ApiClient.request(self, method, url, query_params, headers, post_params, body, _preload_content, _request_timeout)
#     358 """Makes the HTTP request using RESTClient."""
#     359 if method == "GET":
# --> 360     return self.rest_client.GET(
#     361         url,
#     362         query_params=query_params,
#     363         _preload_content=_preload_content,
#     364         _request_timeout=_request_timeout,
#     365         headers=headers,
#     366     )
#     367 elif method == "HEAD":
#     368     return self.rest_client.HEAD(
#     369         url,
#     370         query_params=query_params,
#    (...)    373         headers=headers,
#     374     )
#
# File d:\project\myvenv\Lib\site-packages\pinecone\openapi_support\rest_utils.py:75, in RestClientInterface.GET(self, url, headers, query_params, _preload_content, _request_timeout)
#      72 def GET(
#      73     self, url, headers=None, query_params=None, _preload_content=True, _request_timeout=None
#      74 ):
# ---> 75     return self.request(
#      76         "GET",
#      77         url,
#      78         headers=headers,
#      79         _preload_content=_preload_content,
#      80         _request_timeout=_request_timeout,
#      81         query_params=query_params,
#      82     )
#
# File d:\project\myvenv\Lib\site-packages\pinecone\openapi_support\rest_urllib3.py:267, in Urllib3RestClient.request(self, method, url, query_params, headers, body, post_params, _preload_content, _request_timeout)
#     264     # log response body
#     265     logger.debug("response body: %s", r.data)
# --> 267 return raise_exceptions_or_return(r)
#
# File d:\project\myvenv\Lib\site-packages\pinecone\openapi_support\rest_utils.py:38, in raise_exceptions_or_return(r)
#      36 if not 200 <= r.status <= 299:
#      37     if r.status == 401:
# ---> 38         raise UnauthorizedException(http_resp=r)
#      40     if r.status == 403:
#      41         raise ForbiddenException(http_resp=r)
#
# UnauthorizedException: (401)
# Reason: Unauthorized
# HTTP response headers: HTTPHeaderDict({'x-pinecone-api-version': '2025-04', 'x-cloud-trace-context': 'eae734696c37cbcad6438be913f46c79', 'date': 'Tue, 28 Oct 2025 03:36:18 GMT', 'content-type': 'text/html', 'server': 'Google Frontend', 'Content-Length': '15', 'Via': '1.1 google', 'Alt-Svc': 'h3=":443"; ma=2592000,h3-29=":443"; ma=2592000'})
# HTTP response body: Invalid API Key

# %%
index

# %%
from langchain_pinecone import PineconeVectorStore

vector_store = PineconeVectorStore(index=index, embedding=embeddings)

# %%
vector_store

# %%
from langchain_core.documents import Document

document_1 = Document(
    page_content="I had chocolate chip pancakes and scrambled eggs for breakfast this morning.",
    metadata={"source": "tweet"},
)

document_2 = Document(
    page_content="The weather forecast for tomorrow is cloudy and overcast, with a high of 62 degrees.",
    metadata={"source": "news"},
)

document_3 = Document(
    page_content="Building an exciting new project with LangChain - come check it out!",
    metadata={"source": "tweet"},
)

document_4 = Document(
    page_content="Robbers broke into the city bank and stole $1 million in cash.",
    metadata={"source": "news"},
)

document_5 = Document(
    page_content="Wow! That was an amazing movie. I can't wait to see it again.",
    metadata={"source": "tweet"},
)

document_6 = Document(
    page_content="Is the new iPhone worth the price? Read this review to find out.",
    metadata={"source": "website"},
)

document_7 = Document(
    page_content="The top 10 soccer players in the world right now.",
    metadata={"source": "website"},
)

document_8 = Document(
    page_content="LangGraph is the best framework for building stateful, agentic applications!",
    metadata={"source": "tweet"},
)

document_9 = Document(
    page_content="The stock market is down 500 points today due to fears of a recession.",
    metadata={"source": "news"},
)

document_10 = Document(
    page_content="I have a bad feeling I am going to get deleted :(",
    metadata={"source": "tweet"},
)

documents = [
    document_1,
    document_2,
    document_3,
    document_4,
    document_5,
    document_6,
    document_7,
    document_8,
    document_9,
    document_10,
]

# %%
vector_store.add_documents(documents=documents)
# Out:
# ['319fd410-cf6f-4e54-a1ad-56c3573943e9',
#  'da12c62d-6b7e-45dc-834a-c0e7c145f606',
#  'c4e76fea-0f15-4404-a8db-f83462bb7553',
#  '91f15ee8-9617-4c16-8fa3-65573c97093f',
#  'c2b0f737-3ade-4d32-ae95-0656782cac6f',
#  '05e6dcfc-6e9f-45c6-9147-421ce1d7a7ef',
#  'd542df32-3a84-4fe6-95c6-5ad00fca866f',
#  '5108e39c-5d2b-4675-875a-adeed65518e2',
#  'ab3af2be-29ed-451f-87d1-8b18ad388e7c',
#  '75f3a6bf-a79f-4a60-a976-ecc14e1db909']

# %%
### Query Directly
results = vector_store.similarity_search(
    "LangChain provides abstractions to make working with LLMs easy",
    k=2,
    filter={"source": "tweet"},
)
for res in results:
    print(f"* {res.page_content} [{res.metadata}]")
# Out:
# * Building an exciting new project with LangChain - come check it out! [{'source': 'tweet'}]
# * LangGraph is the best framework for building stateful, agentic applications! [{'source': 'tweet'}]

# %%
results = vector_store.similarity_search_with_score(
    "Will it be hot tomorrow?", k=1, filter={"source": "news"}
)
for res, score in results:
    print(f"* [SIM={score:3f}] {res.page_content} [{res.metadata}]")
# Out:
# * [SIM=0.572665] The weather forecast for tomorrow is cloudy and overcast, with a high of 62 degrees. [{'source': 'news'}]

# %%
### Retriever
retriever = vector_store.as_retriever(
    search_type="similarity_score_threshold",
    search_kwargs={"k": 1, "score_threshold": 0.4},
)
retriever.invoke("Stealing from the bank is a crime", filter={"source": "news"})
# Out:
# [Document(id='91f15ee8-9617-4c16-8fa3-65573c97093f', metadata={'source': 'news'}, page_content='Robbers broke into the city bank and stole $1 million in cash.')]
