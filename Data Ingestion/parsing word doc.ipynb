# %% [markdown]
# ### Word Document Processing

# %%
from langchain_community.document_loaders import Docx2txtLoader, UnstructuredWordDocumentLoader

# %%
import os
os.makedirs("data/word_docs",exist_ok=True)

# %%
#Method 1 : Using DocxtxtLoader

try:
    docx_loader=Docx2txtLoader("data/word_docs/proposal.docx")
    docs=docx_loader.load()
    print(f"Loaded {len(docs)} documents")
    print(f"Content Preview: {docs[0].page_content[:200]}...")
    print(f"Metadata: {docs[0].metadata}")

except Exception as e:
    print(f"Error:{e}")
# Out:
# Loaded 1 documents
# Content Preview: Project Proposal: RAG Implementation
#
# Executive Summary
#
# This proposal outlines the implementation of a Retrieval-Augmented Generation system for our organization.
#
# Objectives
#
# Key objectives include:...
# Metadata: {'source': 'data/word_docs/proposal.docx'}

# %%
### Method 2: Unstructured Word Doc Loader

try:
    unstructured_loader=UnstructuredWordDocumentLoader("data/word_docs/proposal.docx",mode="elements") 
    #mode is just to preserve the structure of the doc
    unstructured_doc=unstructured_loader.load()
    print(f"Loaded {len(unstructured_doc)} elements")
    for i,doc in enumerate(unstructured_doc[:3]):
        print(f"\nElement {i+1}:")
        print(f"Type: {doc.metadata.get('category','unknown')}")
        print(f"Content: {doc.page_content[:100]}...")

except Exception as e:
    print(f"Error:{e}")
# Out:
# Loaded 20 elements
#
# Element 1:
# Type: Title
# Content: Project Proposal: RAG Implementation...
#
# Element 2:
# Type: Title
# Content: Executive Summary...
#
# Element 3:
# Type: NarrativeText
# Content: This proposal outlines the implementation of a Retrieval-Augmented Generation system for our organiz...

# %%
unstructured_doc[0]
# Out:
# Document(metadata={'source': 'data/word_docs/proposal.docx', 'category_depth': 0, 'file_directory': 'data/word_docs', 'filename': 'proposal.docx', 'last_modified': '2025-10-11T00:35:33', 'languages': ['eng'], 'filetype': 'application/vnd.openxmlformats-officedocument.wordprocessingml.document', 'category': 'Title', 'element_id': 'bb0410bfd160ef866f8d4357b0949db2'}, page_content='Project Proposal: RAG Implementation')
